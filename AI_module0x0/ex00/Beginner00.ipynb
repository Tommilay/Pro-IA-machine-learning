# %%
import pandas as pd
import seaborn as sns

# %%
Salary_dataset = pd.read_csv("Salary_dataset.csv")
Salary_dataset.head()
sns.set_style("darkgrid")
sns.jointplot(Salary_dataset, x="YearsExperience", y="Salary", color="#9B90C2")
