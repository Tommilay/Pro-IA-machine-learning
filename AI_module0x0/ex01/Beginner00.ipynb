# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("Salary_dataset.csv")

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = sns.regplot(data, x="YearsExperience", y="Salary")
reg.set(
    title="Linear Regression: Yeas of Experience vs Salary",
    xlabel="Years of Experience",
    ylabel="Salary"
)
# Out:
# [Text(0.5, 1.0, 'Linear Regression: Yeas of Experience vs Salary'),
#  Text(0.5, 0, 'Years of Experience'),
#  Text(0, 0.5, 'Salary')]
